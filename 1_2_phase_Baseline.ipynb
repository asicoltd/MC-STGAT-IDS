# %% [markdown]
# Note: In guideline it was mentioned to, reproduce one baseline (e.g., plain GCN or GraphSAGE) end-to-end on Dataset A. But we need to build the graph to use on GCN or GraphSAGE, so we, built the graph at 1_1_phase_graph_build.ipynb and then used that in this notebook

# %% [markdown]
# ### GCN Baseline

# %% [markdown]
# GCN – Binary Graph Classification (Attack vs Benign) with Weighted BCE

# %%
import os
import pickle
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_DIR = "GothamDataset2025/processed_features/gotham_graphs"
BATCH_SIZE = 16          # smaller batch for stability
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4
EPOCHS = 200
PATIENCE = 20
HIDDEN_DIM = 64
NUM_LAYERS = 2
DROPOUT = 0.2
LR_STEP = 30
LR_GAMMA = 0.5

#  LOAD DATA & NORMALISE 
def load_graphs(split):
    with open(os.path.join(DATA_DIR, f"{split}_graphs.pkl"), 'rb') as f:
        return pickle.load(f)

with open(os.path.join(DATA_DIR, "norm_stats.json"), 'r') as f:
    norm_stats = json.load(f)

node_mean = torch.tensor(norm_stats["node_mean"], dtype=torch.float)
node_std  = torch.tensor(norm_stats["node_std"], dtype=torch.float)
node_dim  = norm_stats["node_dim"]

def normalise_graphs(graphs):
    for g in graphs:
        g.x = (g.x - node_mean) / (node_std + 1e-8)
        g.x = torch.clamp(g.x, -10, 10)

train_graphs = load_graphs('train')
val_graphs   = load_graphs('val')
test_graphs  = load_graphs('test')
print(f"Train: {len(train_graphs)}, Val: {len(val_graphs)}, Test: {len(test_graphs)}")

normalise_graphs(train_graphs)
normalise_graphs(val_graphs)
normalise_graphs(test_graphs)

#  BINARY LABELS (use g.y) 
# g.y == 1 if any edge in the graph is attack, else 0
for g in train_graphs:
    g.y = g.y.float().unsqueeze(1)   # shape (1,1) for binary BCE
for g in val_graphs:
    g.y = g.y.float().unsqueeze(1)
for g in test_graphs:
    g.y = g.y.float().unsqueeze(1)

# Compute pos_weight for imbalance
pos_count = sum(g.y.item() for g in train_graphs)
neg_count = len(train_graphs) - pos_count
pos_weight = torch.tensor([neg_count / (pos_count + 1e-6)]).to(DEVICE)
print(f"Positive graphs: {pos_count}, Negative: {neg_count}, pos_weight: {pos_weight.item():.2f}")

train_loader = DataLoader(train_graphs, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_graphs, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_graphs, batch_size=BATCH_SIZE, shuffle=False)

#  GCN MODEL (Binary output) 
class GCNBinary(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_layers, dropout):
        super(GCNBinary, self).__init__()
        self.convs = nn.ModuleList()
        self.convs.append(GCNConv(in_channels, hidden_channels))
        for _ in range(num_layers - 2):
            self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.bns = nn.ModuleList([nn.BatchNorm1d(hidden_channels) for _ in range(num_layers)])
        self.dropout = dropout
        self.lin = nn.Linear(hidden_channels, 1)

    def forward(self, x, edge_index, batch):
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            x = self.bns[i](x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = global_mean_pool(x, batch)
        x = self.lin(x)
        return x

model = GCNBinary(
    in_channels=node_dim,
    hidden_channels=HIDDEN_DIM,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT
).to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=LR_STEP, gamma=LR_GAMMA)

best_val_loss = float('inf')
patience_counter = 0

for epoch in range(1, EPOCHS + 1):
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(DEVICE)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    model.eval()
    val_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for data in val_loader:
            data = data.to(DEVICE)
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y)
            val_loss += loss.item() * data.num_graphs
            pred = torch.sigmoid(out).round().cpu().numpy()
            all_preds.extend(pred)
            all_labels.extend(data.y.cpu().numpy())
    val_loss /= len(val_loader.dataset)

    # Compute validation F1
    val_f1 = f1_score(all_labels, all_preds, zero_division=0)

    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    print(f"Epoch {epoch:03d} | LR: {current_lr:.6f} | Train Loss: {avg_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), os.path.join(DATA_DIR, "gcn_binary_best.pth"))
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            print(f"Early stopping at epoch {epoch}")
            break

#  EVALUATION ON TEST SET 
model.load_state_dict(torch.load(os.path.join(DATA_DIR, "gcn_binary_best.pth")))
model.eval()

all_preds = []
all_labels = []
with torch.no_grad():
    for data in test_loader:
        data = data.to(DEVICE)
        out = model(data.x, data.edge_index, data.batch)
        pred = torch.sigmoid(out).round().cpu().numpy()
        all_preds.extend(pred)
        all_labels.extend(data.y.cpu().numpy())

all_preds = np.array(all_preds).flatten()
all_labels = np.array(all_labels).flatten()

acc = accuracy_score(all_labels, all_preds)
rec = recall_score(all_labels, all_preds, zero_division=0)
prec = precision_score(all_labels, all_preds, zero_division=0)
f1 = f1_score(all_labels, all_preds, zero_division=0)
try:
    auc = roc_auc_score(all_labels, all_preds)
except:
    auc = 0.0

print("\n========== Binary GCN Results ==========")
print(f"Accuracy:  {acc:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"Precision: {prec:.4f}")
print(f"F1:        {f1:.4f}")
print(f"AUC:       {auc:.4f}")
print("=========================================")

results = {
    "model": "GCN_binary",
    "accuracy": acc,
    "recall": rec,
    "precision": prec,
    "f1": f1,
    "auc": auc
}
with open(os.path.join(DATA_DIR, "gcn_binary_results.json"), "w") as f:
    json.dump(results, f, indent=4)
print("Results saved to gcn_binary_results.json")
# Out:
# Train: 471, Val: 101, Test: 101
# Positive graphs: 156.0, Negative: 315.0, pos_weight: 2.02
# Epoch 001 | LR: 0.000100 | Train Loss: 1.1217 | Val Loss: 1.6083 | Val F1: 0.6883
# Epoch 002 | LR: 0.000100 | Train Loss: 1.0088 | Val Loss: 1.1676 | Val F1: 0.0323
# Epoch 003 | LR: 0.000100 | Train Loss: 0.9884 | Val Loss: 1.2487 | Val F1: 0.4938
# Epoch 004 | LR: 0.000100 | Train Loss: 0.9138 | Val Loss: 1.2969 | Val F1: 0.6600
# Epoch 005 | LR: 0.000100 | Train Loss: 0.8433 | Val Loss: 1.2774 | Val F1: 0.5122
# Epoch 006 | LR: 0.000100 | Train Loss: 0.8202 | Val Loss: 1.3491 | Val F1: 0.6452
# Epoch 007 | LR: 0.000100 | Train Loss: 0.7803 | Val Loss: 1.2143 | Val F1: 0.6593
# Epoch 008 | LR: 0.000100 | Train Loss: 0.7570 | Val Loss: 1.1206 | Val F1: 0.5647
# Epoch 009 | LR: 0.000100 | Train Loss: 0.7321 | Val Loss: 1.1277 | Val F1: 0.6292
# Epoch 010 | LR: 0.000100 | Train Loss: 0.7139 | Val Loss: 1.1699 | Val F1: 0.4557
# Epoch 011 | LR: 0.000100 | Train Loss: 0.7140 | Val Loss: 1.0918 | Val F1: 0.5647
# Epoch 012 | LR: 0.000100 | Train Loss: 0.6736 | Val Loss: 1.1194 | Val F1: 0.4557
# Epoch 013 | LR: 0.000100 | Train Loss: 0.6502 | Val Loss: 1.0723 | Val F1: 0.5647
# Epoch 014 | LR: 0.000100 | Train Loss: 0.6670 | Val Loss: 1.0801 | Val F1: 0.6292
# Epoch 015 | LR: 0.000100 | Train Loss: 0.6469 | Val Loss: 1.0572 | Val F1: 0.6593
# Epoch 016 | LR: 0.000100 | Train Loss: 0.6167 | Val Loss: 1.0803 | Val F1: 0.5301
# Epoch 017 | LR: 0.000100 | Train Loss: 0.5864 | Val Loss: 1.0261 | Val F1: 0.6882
# Epoch 018 | LR: 0.000100 | Train Loss: 0.5899 | Val Loss: 1.0566 | Val F1: 0.6444
# Epoch 019 | LR: 0.000100 | Train Loss: 0.5550 | Val Loss: 1.0997 | Val F1: 0.4938
# Epoch 020 | LR: 0.000100 | Train Loss: 0.5547 | Val Loss: 0.9757 | Val F1: 0.8491
# Epoch 021 | LR: 0.000100 | Train Loss: 0.5661 | Val Loss: 0.9968 | Val F1: 0.7423
# Epoch 022 | LR: 0.000100 | Train Loss: 0.5520 | Val Loss: 1.0792 | Val F1: 0.5476
# Epoch 023 | LR: 0.000100 | Train Loss: 0.5201 | Val Loss: 1.0582 | Val F1: 0.5814
# Epoch 024 | LR: 0.000100 | Train Loss: 0.5682 | Val Loss: 1.1141 | Val F1: 0.4359
# Epoch 025 | LR: 0.000100 | Train Loss: 0.4960 | Val Loss: 1.0466 | Val F1: 0.5814
# Epoch 026 | LR: 0.000100 | Train Loss: 0.4949 | Val Loss: 1.0797 | Val F1: 0.5301
# Epoch 027 | LR: 0.000100 | Train Loss: 0.4724 | Val Loss: 1.1193 | Val F1: 0.4938
# Epoch 028 | LR: 0.000100 | Train Loss: 0.4721 | Val Loss: 1.1148 | Val F1: 0.5122
# Epoch 029 | LR: 0.000100 | Train Loss: 0.4440 | Val Loss: 1.1635 | Val F1: 0.2059
# Epoch 030 | LR: 0.000050 | Train Loss: 0.4354 | Val Loss: 1.0249 | Val F1: 0.7021
# Epoch 031 | LR: 0.000050 | Train Loss: 0.4627 | Val Loss: 1.1436 | Val F1: 0.5301
# Epoch 032 | LR: 0.000050 | Train Loss: 0.4480 | Val Loss: 1.1979 | Val F1: 0.1515
# Epoch 033 | LR: 0.000050 | Train Loss: 0.4615 | Val Loss: 1.1249 | Val F1: 0.4938
# Epoch 034 | LR: 0.000050 | Train Loss: 0.4354 | Val Loss: 1.0334 | Val F1: 0.5977
# Epoch 035 | LR: 0.000050 | Train Loss: 0.4484 | Val Loss: 1.0573 | Val F1: 0.5814
# Epoch 036 | LR: 0.000050 | Train Loss: 0.4604 | Val Loss: 1.2045 | Val F1: 0.1515
# Epoch 037 | LR: 0.000050 | Train Loss: 0.4213 | Val Loss: 1.1637 | Val F1: 0.2571
# Epoch 038 | LR: 0.000050 | Train Loss: 0.3946 | Val Loss: 1.1063 | Val F1: 0.5476
# Epoch 039 | LR: 0.000050 | Train Loss: 0.3836 | Val Loss: 1.0757 | Val F1: 0.5814
# Epoch 040 | LR: 0.000050 | Train Loss: 0.4255 | Val Loss: 1.1333 | Val F1: 0.5476
# Early stopping at epoch 40
#
# ========== Binary GCN Results ==========
# Accuracy:  0.6238
# Recall:    0.1190
# Precision: 0.8333
# F1:        0.2083
# AUC:       0.5510
# =========================================
# Results saved to gcn_binary_results.json

# %% [markdown]
# GCN – Multi‑Label Graph Classification (with per‑class weighted BCE)

# %%
import os
import pickle
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool
from sklearn.metrics import f1_score, recall_score, precision_score, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_DIR = "GothamDataset2025/processed_features/gotham_graphs"
BATCH_SIZE = 16
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4
EPOCHS = 200
PATIENCE = 20
HIDDEN_DIM = 64
NUM_LAYERS = 2
DROPOUT = 0.2
LR_STEP = 30
LR_GAMMA = 0.5

#  LOAD & NORMALISE 
def load_graphs(split):
    with open(os.path.join(DATA_DIR, f"{split}_graphs.pkl"), 'rb') as f:
        return pickle.load(f)

with open(os.path.join(DATA_DIR, "norm_stats.json"), 'r') as f:
    norm_stats = json.load(f)

node_mean = torch.tensor(norm_stats["node_mean"], dtype=torch.float)
node_std  = torch.tensor(norm_stats["node_std"], dtype=torch.float)
node_dim  = norm_stats["node_dim"]

def normalise_graphs(graphs):
    for g in graphs:
        g.x = (g.x - node_mean) / (node_std + 1e-8)
        g.x = torch.clamp(g.x, -10, 10)

train_graphs = load_graphs('train')
val_graphs   = load_graphs('val')
test_graphs  = load_graphs('test')
print(f"Train: {len(train_graphs)}, Val: {len(val_graphs)}, Test: {len(test_graphs)}")

normalise_graphs(train_graphs)
normalise_graphs(val_graphs)
normalise_graphs(test_graphs)

#  BUILD MULTI-HOT LABELS 
# Use edge_attack_names from graphs
attack_names = set()
for g in train_graphs:
    for name in g.edge_attack_names:
        if name != 'Benign':
            attack_names.add(name)
attack_names = sorted(list(attack_names))
num_classes = len(attack_names)
print(f"Number of attack classes: {num_classes}")
print("Classes:", attack_names)

class_to_idx = {name: i for i, name in enumerate(attack_names)}

def get_multihot_labels(graph):
    labels = torch.zeros(num_classes, dtype=torch.float)
    for name in graph.edge_attack_names:
        if name != 'Benign' and name in class_to_idx:
            labels[class_to_idx[name]] = 1.0
    return labels.unsqueeze(0)   # (1, num_classes)

for g in train_graphs:
    g.y_multihot = get_multihot_labels(g)
for g in val_graphs:
    g.y_multihot = get_multihot_labels(g)
for g in test_graphs:
    g.y_multihot = get_multihot_labels(g)

# Compute per‑class pos_weight for BCEWithLogitsLoss
# Use positive count from training set
pos_counts = torch.stack([g.y_multihot for g in train_graphs]).sum(0)
neg_counts = len(train_graphs) - pos_counts
pos_weight = neg_counts / (pos_counts + 1e-6)
print("Pos_weight per class:", pos_weight.tolist())

train_loader = DataLoader(train_graphs, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_graphs, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_graphs, batch_size=BATCH_SIZE, shuffle=False)

#  GCN MODEL (Multi‑label) 
class GCNMulti(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers, dropout):
        super(GCNMulti, self).__init__()
        self.convs = nn.ModuleList()
        self.convs.append(GCNConv(in_channels, hidden_channels))
        for _ in range(num_layers - 2):
            self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.bns = nn.ModuleList([nn.BatchNorm1d(hidden_channels) for _ in range(num_layers)])
        self.dropout = dropout
        self.lin = nn.Linear(hidden_channels, out_channels)

    def forward(self, x, edge_index, batch):
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            x = self.bns[i](x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = global_mean_pool(x, batch)
        x = self.lin(x)
        return x

model = GCNMulti(
    in_channels=node_dim,
    hidden_channels=HIDDEN_DIM,
    out_channels=num_classes,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT
).to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight.to(DEVICE))
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=LR_STEP, gamma=LR_GAMMA)

best_val_loss = float('inf')
patience_counter = 0

for epoch in range(1, EPOCHS + 1):
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(DEVICE)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y_multihot)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    model.eval()
    val_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for data in val_loader:
            data = data.to(DEVICE)
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y_multihot)
            val_loss += loss.item() * data.num_graphs
            preds = torch.sigmoid(out).cpu().numpy()
            labels = data.y_multihot.cpu().numpy()
            all_preds.append(preds)
            all_labels.append(labels)
    val_loss /= len(val_loader.dataset)

    all_preds = np.vstack(all_preds)
    all_labels = np.vstack(all_labels)
    pred_binary = (all_preds >= 0.5).astype(int)
    macro_f1 = f1_score(all_labels, pred_binary, average='macro', zero_division=0)

    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    print(f"Epoch {epoch:03d} | LR: {current_lr:.6f} | Train Loss: {avg_loss:.4f} | Val Loss: {val_loss:.4f} | Val Macro F1: {macro_f1:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), os.path.join(DATA_DIR, "gcn_multilabel_best.pth"))
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            print(f"Early stopping at epoch {epoch}")
            break

#  EVALUATION ON TEST SET 
model.load_state_dict(torch.load(os.path.join(DATA_DIR, "gcn_multilabel_best.pth")))
model.eval()

all_preds = []
all_labels = []
with torch.no_grad():
    for data in test_loader:
        data = data.to(DEVICE)
        out = model(data.x, data.edge_index, data.batch)
        preds = torch.sigmoid(out).cpu().numpy()
        labels = data.y_multihot.cpu().numpy()
        all_preds.append(preds)
        all_labels.append(labels)

all_preds = np.vstack(all_preds)
all_labels = np.vstack(all_labels)
pred_binary = (all_preds >= 0.5).astype(int)

per_class_recall = recall_score(all_labels, pred_binary, average=None, zero_division=0)
per_class_precision = precision_score(all_labels, pred_binary, average=None, zero_division=0)
per_class_f1 = f1_score(all_labels, pred_binary, average=None, zero_division=0)

macro_f1 = f1_score(all_labels, pred_binary, average='macro', zero_division=0)
macro_recall = recall_score(all_labels, pred_binary, average='macro', zero_division=0)
macro_precision = precision_score(all_labels, pred_binary, average='macro', zero_division=0)

# PR‑AUC per class
pr_auc_per_class = []
for i in range(num_classes):
    if np.sum(all_labels[:, i]) > 0:
        try:
            auc = roc_auc_score(all_labels[:, i], all_preds[:, i])
        except:
            auc = 0.0
    else:
        auc = 0.0
    pr_auc_per_class.append(auc)
macro_pr_auc = np.mean(pr_auc_per_class)

print("\n========== Multi‑Label GCN Results ==========")
print(f"Macro F1:        {macro_f1:.4f}")
print(f"Macro Recall:    {macro_recall:.4f}")
print(f"Macro Precision: {macro_precision:.4f}")
print(f"Macro PR‑AUC:    {macro_pr_auc:.4f}")
print("\nPer‑class metrics:")
for i, name in enumerate(attack_names):
    print(f"  {name:20s} | Recall: {per_class_recall[i]:.4f} | Prec: {per_class_precision[i]:.4f} | F1: {per_class_f1[i]:.4f} | PR‑AUC: {pr_auc_per_class[i]:.4f}")
print("==============================================")

results = {
    "model": "GCN_multilabel",
    "loss": "BCEWithLogitsLoss (pos_weight)",
    "macro_f1": macro_f1,
    "macro_recall": macro_recall,
    "macro_precision": macro_precision,
    "macro_pr_auc": macro_pr_auc,
    "per_class": {
        name: {"recall": per_class_recall[i], "precision": per_class_precision[i], "f1": per_class_f1[i], "pr_auc": pr_auc_per_class[i]}
        for i, name in enumerate(attack_names)
    }
}
with open(os.path.join(DATA_DIR, "gcn_multilabel_results.json"), "w") as f:
    json.dump(results, f, indent=4)
print("Results saved to gcn_multilabel_results.json")
# Out:
# Train: 471, Val: 101, Test: 101
# Number of attack classes: 14
# Classes: ['C&C Communication', 'CoAP Amplification', 'File Download', 'Ingress Tool Transfer', 'Merlin C&C Communication', 'Merlin ICMP Flooding', 'Merlin TCP Flooding', 'Merlin UDP Flooding', 'Mirai C&C Communication', 'Reporting', 'TCP Scan', 'Telnet Brute Force', 'UDP Scan', 'Unknown']
# Pos_weight per class: [[23.789470672607422, 469.9995422363281, 93.19998168945312, 30.39999771118164, 5.633802890777588, 77.49998474121094, 66.28570556640625, 155.9999542236328, 38.249996185302734, 35.23076629638672, 23.789470672607422, 18.624998092651367, 11.729729652404785, 51.33332824707031]]
# Epoch 001 | LR: 0.000100 | Train Loss: 1.4411 | Val Loss: 2.1282 | Val Macro F1: 0.0463
# Epoch 002 | LR: 0.000100 | Train Loss: 1.5158 | Val Loss: 2.1286 | Val Macro F1: 0.0467
# Epoch 003 | LR: 0.000100 | Train Loss: 1.4696 | Val Loss: 2.7953 | Val Macro F1: 0.0459
# Epoch 004 | LR: 0.000100 | Train Loss: 1.3273 | Val Loss: 2.5214 | Val Macro F1: 0.0447
# Epoch 005 | LR: 0.000100 | Train Loss: 1.3822 | Val Loss: 2.7978 | Val Macro F1: 0.0450
# Epoch 006 | LR: 0.000100 | Train Loss: 1.3603 | Val Loss: 2.7537 | Val Macro F1: 0.0466
# Epoch 007 | LR: 0.000100 | Train Loss: 1.4626 | Val Loss: 2.9628 | Val Macro F1: 0.0523
# Epoch 008 | LR: 0.000100 | Train Loss: 1.3126 | Val Loss: 2.3068 | Val Macro F1: 0.0447
# Epoch 009 | LR: 0.000100 | Train Loss: 1.4325 | Val Loss: 2.8700 | Val Macro F1: 0.0447
# Epoch 010 | LR: 0.000100 | Train Loss: 1.2907 | Val Loss: 2.7052 | Val Macro F1: 0.0447
# Epoch 011 | LR: 0.000100 | Train Loss: 1.3229 | Val Loss: 3.1670 | Val Macro F1: 0.0450
# Epoch 012 | LR: 0.000100 | Train Loss: 1.1659 | Val Loss: 2.8707 | Val Macro F1: 0.0447
# Epoch 013 | LR: 0.000100 | Train Loss: 1.3782 | Val Loss: 3.2446 | Val Macro F1: 0.0447
# Epoch 014 | LR: 0.000100 | Train Loss: 1.2217 | Val Loss: 3.4279 | Val Macro F1: 0.0450
# Epoch 015 | LR: 0.000100 | Train Loss: 1.2848 | Val Loss: 3.1613 | Val Macro F1: 0.0447
# Epoch 016 | LR: 0.000100 | Train Loss: 1.2575 | Val Loss: 3.7675 | Val Macro F1: 0.0466
# Epoch 017 | LR: 0.000100 | Train Loss: 1.4068 | Val Loss: 3.9107 | Val Macro F1: 0.0466
# Epoch 018 | LR: 0.000100 | Train Loss: 1.3285 | Val Loss: 3.1722 | Val Macro F1: 0.0447
# Epoch 019 | LR: 0.000100 | Train Loss: 1.4939 | Val Loss: 3.8359 | Val Macro F1: 0.0447
# Epoch 020 | LR: 0.000100 | Train Loss: 1.2108 | Val Loss: 2.6431 | Val Macro F1: 0.0447
# Epoch 021 | LR: 0.000100 | Train Loss: 1.1285 | Val Loss: 3.0994 | Val Macro F1: 0.0447
# Early stopping at epoch 21
#
# ========== Multi‑Label GCN Results ==========
# Macro F1:        0.0221
# Macro Recall:    0.0187
# Macro Precision: 0.0271
# Macro PR‑AUC:    0.0348
#
# Per‑class metrics:
#   C&C Communication    | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   CoAP Amplification   | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   File Download        | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Ingress Tool Transfer | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin C&C Communication | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin ICMP Flooding | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin TCP Flooding  | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin UDP Flooding  | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Mirai C&C Communication | Recall: 0.2619 | Prec: 0.3793 | F1: 0.3099 | PR‑AUC: 0.4879
#   Reporting            | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   TCP Scan             | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Telnet Brute Force   | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   UDP Scan             | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Unknown              | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
# ==============================================
# Results saved to gcn_multilabel_results.json

# %% [markdown]
# ### GraphSAGE Baseline

# %% [markdown]
# GraphSAGE – Binary Graph Classification (Attack vs Benign) with Weighted BCE

# %%
import os
import pickle
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import DataLoader
from torch_geometric.nn import SAGEConv, global_mean_pool
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_DIR = "GothamDataset2025/processed_features/gotham_graphs"
BATCH_SIZE = 16
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4
EPOCHS = 200
PATIENCE = 20
HIDDEN_DIM = 64
NUM_LAYERS = 2
DROPOUT = 0.2
LR_STEP = 30
LR_GAMMA = 0.5

#  LOAD & NORMALISE 
def load_graphs(split):
    with open(os.path.join(DATA_DIR, f"{split}_graphs.pkl"), 'rb') as f:
        return pickle.load(f)

with open(os.path.join(DATA_DIR, "norm_stats.json"), 'r') as f:
    norm_stats = json.load(f)

node_mean = torch.tensor(norm_stats["node_mean"], dtype=torch.float)
node_std  = torch.tensor(norm_stats["node_std"], dtype=torch.float)
node_dim  = norm_stats["node_dim"]

def normalise_graphs(graphs):
    for g in graphs:
        g.x = (g.x - node_mean) / (node_std + 1e-8)
        g.x = torch.clamp(g.x, -10, 10)

train_graphs = load_graphs('train')
val_graphs   = load_graphs('val')
test_graphs  = load_graphs('test')
print(f"Train: {len(train_graphs)}, Val: {len(val_graphs)}, Test: {len(test_graphs)}")

normalise_graphs(train_graphs)
normalise_graphs(val_graphs)
normalise_graphs(test_graphs)

# Binary labels
for g in train_graphs:
    g.y = g.y.float().unsqueeze(1)
for g in val_graphs:
    g.y = g.y.float().unsqueeze(1)
for g in test_graphs:
    g.y = g.y.float().unsqueeze(1)

pos_count = sum(g.y.item() for g in train_graphs)
neg_count = len(train_graphs) - pos_count
pos_weight = torch.tensor([neg_count / (pos_count + 1e-6)]).to(DEVICE)
print(f"Positive graphs: {pos_count}, Negative: {neg_count}, pos_weight: {pos_weight.item():.2f}")

train_loader = DataLoader(train_graphs, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_graphs, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_graphs, batch_size=BATCH_SIZE, shuffle=False)

#  GraphSAGE MODEL (Binary) 
class GraphSAGEBinary(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_layers, dropout):
        super(GraphSAGEBinary, self).__init__()
        self.convs = nn.ModuleList()
        self.convs.append(SAGEConv(in_channels, hidden_channels))
        for _ in range(num_layers - 2):
            self.convs.append(SAGEConv(hidden_channels, hidden_channels))
        self.convs.append(SAGEConv(hidden_channels, hidden_channels))
        self.bns = nn.ModuleList([nn.BatchNorm1d(hidden_channels) for _ in range(num_layers)])
        self.dropout = dropout
        self.lin = nn.Linear(hidden_channels, 1)

    def forward(self, x, edge_index, batch):
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            x = self.bns[i](x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = global_mean_pool(x, batch)
        x = self.lin(x)
        return x

model = GraphSAGEBinary(
    in_channels=node_dim,
    hidden_channels=HIDDEN_DIM,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT
).to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=LR_STEP, gamma=LR_GAMMA)

best_val_loss = float('inf')
patience_counter = 0

for epoch in range(1, EPOCHS + 1):
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(DEVICE)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    model.eval()
    val_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for data in val_loader:
            data = data.to(DEVICE)
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y)
            val_loss += loss.item() * data.num_graphs
            pred = torch.sigmoid(out).round().cpu().numpy()
            all_preds.extend(pred)
            all_labels.extend(data.y.cpu().numpy())
    val_loss /= len(val_loader.dataset)
    val_f1 = f1_score(all_labels, all_preds, zero_division=0)

    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    print(f"Epoch {epoch:03d} | LR: {current_lr:.6f} | Train Loss: {avg_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), os.path.join(DATA_DIR, "graphsage_binary_best.pth"))
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            print(f"Early stopping at epoch {epoch}")
            break

#  EVALUATION 
model.load_state_dict(torch.load(os.path.join(DATA_DIR, "graphsage_binary_best.pth")))
model.eval()

all_preds = []
all_labels = []
with torch.no_grad():
    for data in test_loader:
        data = data.to(DEVICE)
        out = model(data.x, data.edge_index, data.batch)
        pred = torch.sigmoid(out).round().cpu().numpy()
        all_preds.extend(pred)
        all_labels.extend(data.y.cpu().numpy())

all_preds = np.array(all_preds).flatten()
all_labels = np.array(all_labels).flatten()

acc = accuracy_score(all_labels, all_preds)
rec = recall_score(all_labels, all_preds, zero_division=0)
prec = precision_score(all_labels, all_preds, zero_division=0)
f1 = f1_score(all_labels, all_preds, zero_division=0)
try:
    auc = roc_auc_score(all_labels, all_preds)
except:
    auc = 0.0

print("\n========== Binary GraphSAGE Results ==========")
print(f"Accuracy:  {acc:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"Precision: {prec:.4f}")
print(f"F1:        {f1:.4f}")
print(f"AUC:       {auc:.4f}")
print("===============================================")

results = {
    "model": "GraphSAGE_binary",
    "accuracy": acc,
    "recall": rec,
    "precision": prec,
    "f1": f1,
    "auc": auc
}
with open(os.path.join(DATA_DIR, "graphsage_binary_results.json"), "w") as f:
    json.dump(results, f, indent=4)
print("Results saved to graphsage_binary_results.json")
# Out:
# Train: 471, Val: 101, Test: 101
# Positive graphs: 156.0, Negative: 315.0, pos_weight: 2.02
# Epoch 001 | LR: 0.000100 | Train Loss: 0.9684 | Val Loss: 1.0402 | Val F1: 0.7531
# Epoch 002 | LR: 0.000100 | Train Loss: 0.8986 | Val Loss: 1.0653 | Val F1: 0.8496
# Epoch 003 | LR: 0.000100 | Train Loss: 0.8671 | Val Loss: 0.9794 | Val F1: 0.7531
# Epoch 004 | LR: 0.000100 | Train Loss: 0.8496 | Val Loss: 1.0273 | Val F1: 0.8704
# Epoch 005 | LR: 0.000100 | Train Loss: 0.7913 | Val Loss: 0.9871 | Val F1: 0.9677
# Epoch 006 | LR: 0.000100 | Train Loss: 0.7347 | Val Loss: 0.9791 | Val F1: 0.9204
# Epoch 007 | LR: 0.000100 | Train Loss: 0.7109 | Val Loss: 0.9831 | Val F1: 0.8598
# Epoch 008 | LR: 0.000100 | Train Loss: 0.6771 | Val Loss: 0.9636 | Val F1: 0.8704
# Epoch 009 | LR: 0.000100 | Train Loss: 0.6615 | Val Loss: 0.9338 | Val F1: 0.8909
# Epoch 010 | LR: 0.000100 | Train Loss: 0.6268 | Val Loss: 0.9444 | Val F1: 0.8704
# Epoch 011 | LR: 0.000100 | Train Loss: 0.6126 | Val Loss: 0.8707 | Val F1: 0.9204
# Epoch 012 | LR: 0.000100 | Train Loss: 0.5813 | Val Loss: 0.8399 | Val F1: 0.9391
# Epoch 013 | LR: 0.000100 | Train Loss: 0.5560 | Val Loss: 0.9407 | Val F1: 0.8491
# Epoch 014 | LR: 0.000100 | Train Loss: 0.5405 | Val Loss: 0.8522 | Val F1: 0.8704
# Epoch 015 | LR: 0.000100 | Train Loss: 0.5231 | Val Loss: 0.8271 | Val F1: 0.8909
# Epoch 016 | LR: 0.000100 | Train Loss: 0.5123 | Val Loss: 0.8079 | Val F1: 0.8909
# Epoch 017 | LR: 0.000100 | Train Loss: 0.4867 | Val Loss: 0.7417 | Val F1: 0.9298
# Epoch 018 | LR: 0.000100 | Train Loss: 0.4195 | Val Loss: 0.7843 | Val F1: 0.8807
# Epoch 019 | LR: 0.000100 | Train Loss: 0.4384 | Val Loss: 0.8062 | Val F1: 0.8807
# Epoch 020 | LR: 0.000100 | Train Loss: 0.4511 | Val Loss: 0.7253 | Val F1: 0.8909
# Epoch 021 | LR: 0.000100 | Train Loss: 0.4147 | Val Loss: 0.7012 | Val F1: 0.9204
# Epoch 022 | LR: 0.000100 | Train Loss: 0.4230 | Val Loss: 0.7867 | Val F1: 0.8598
# Epoch 023 | LR: 0.000100 | Train Loss: 0.3923 | Val Loss: 0.7723 | Val F1: 0.8598
# Epoch 024 | LR: 0.000100 | Train Loss: 0.4072 | Val Loss: 0.7699 | Val F1: 0.8598
# Epoch 025 | LR: 0.000100 | Train Loss: 0.4034 | Val Loss: 0.8715 | Val F1: 0.8269
# Epoch 026 | LR: 0.000100 | Train Loss: 0.3663 | Val Loss: 0.7376 | Val F1: 0.8807
# Epoch 027 | LR: 0.000100 | Train Loss: 0.3688 | Val Loss: 0.7795 | Val F1: 0.8598
# Epoch 028 | LR: 0.000100 | Train Loss: 0.3130 | Val Loss: 0.9170 | Val F1: 0.8155
# Epoch 029 | LR: 0.000100 | Train Loss: 0.3768 | Val Loss: 0.8335 | Val F1: 0.8491
# Epoch 030 | LR: 0.000050 | Train Loss: 0.3251 | Val Loss: 0.6901 | Val F1: 0.8909
# Epoch 031 | LR: 0.000050 | Train Loss: 0.3505 | Val Loss: 0.7117 | Val F1: 0.8704
# Epoch 032 | LR: 0.000050 | Train Loss: 0.3300 | Val Loss: 0.7907 | Val F1: 0.8491
# Epoch 033 | LR: 0.000050 | Train Loss: 0.3138 | Val Loss: 0.6361 | Val F1: 0.8909
# Epoch 034 | LR: 0.000050 | Train Loss: 0.3046 | Val Loss: 0.5833 | Val F1: 0.9391
# Epoch 035 | LR: 0.000050 | Train Loss: 0.3247 | Val Loss: 0.7256 | Val F1: 0.8704
# Epoch 036 | LR: 0.000050 | Train Loss: 0.3324 | Val Loss: 0.7862 | Val F1: 0.8491
# Epoch 037 | LR: 0.000050 | Train Loss: 0.2583 | Val Loss: 0.6134 | Val F1: 0.8909
# Epoch 038 | LR: 0.000050 | Train Loss: 0.3096 | Val Loss: 0.8203 | Val F1: 0.8381
# Epoch 039 | LR: 0.000050 | Train Loss: 0.3012 | Val Loss: 0.5453 | Val F1: 0.9391
# Epoch 040 | LR: 0.000050 | Train Loss: 0.2669 | Val Loss: 0.8546 | Val F1: 0.8269
# Epoch 041 | LR: 0.000050 | Train Loss: 0.3261 | Val Loss: 0.6361 | Val F1: 0.8909
# Epoch 042 | LR: 0.000050 | Train Loss: 0.3089 | Val Loss: 0.6592 | Val F1: 0.8909
# Epoch 043 | LR: 0.000050 | Train Loss: 0.3045 | Val Loss: 0.6073 | Val F1: 0.8909
# Epoch 044 | LR: 0.000050 | Train Loss: 0.3011 | Val Loss: 0.7235 | Val F1: 0.8704
# Epoch 045 | LR: 0.000050 | Train Loss: 0.2888 | Val Loss: 0.5555 | Val F1: 0.8909
# Epoch 046 | LR: 0.000050 | Train Loss: 0.2954 | Val Loss: 0.7172 | Val F1: 0.8704
# Epoch 047 | LR: 0.000050 | Train Loss: 0.3237 | Val Loss: 0.6903 | Val F1: 0.8704
# Epoch 048 | LR: 0.000050 | Train Loss: 0.3335 | Val Loss: 0.6220 | Val F1: 0.8909
# Epoch 049 | LR: 0.000050 | Train Loss: 0.2793 | Val Loss: 0.5575 | Val F1: 0.8909
# Epoch 050 | LR: 0.000050 | Train Loss: 0.2916 | Val Loss: 0.6604 | Val F1: 0.8909
# Epoch 051 | LR: 0.000050 | Train Loss: 0.2824 | Val Loss: 0.4938 | Val F1: 0.9391
# Epoch 052 | LR: 0.000050 | Train Loss: 0.2759 | Val Loss: 0.5912 | Val F1: 0.8909
# Epoch 053 | LR: 0.000050 | Train Loss: 0.2925 | Val Loss: 0.7827 | Val F1: 0.8381
# Epoch 054 | LR: 0.000050 | Train Loss: 0.2869 | Val Loss: 0.6661 | Val F1: 0.8909
# Epoch 055 | LR: 0.000050 | Train Loss: 0.2683 | Val Loss: 0.6882 | Val F1: 0.8807
# Epoch 056 | LR: 0.000050 | Train Loss: 0.2428 | Val Loss: 0.8735 | Val F1: 0.8155
# Epoch 057 | LR: 0.000050 | Train Loss: 0.2978 | Val Loss: 0.8640 | Val F1: 0.8269
# Epoch 058 | LR: 0.000050 | Train Loss: 0.2946 | Val Loss: 0.5377 | Val F1: 0.8909
# Epoch 059 | LR: 0.000050 | Train Loss: 0.2395 | Val Loss: 0.8116 | Val F1: 0.8381
# Epoch 060 | LR: 0.000025 | Train Loss: 0.2557 | Val Loss: 0.6255 | Val F1: 0.8909
# Epoch 061 | LR: 0.000025 | Train Loss: 0.2567 | Val Loss: 0.7870 | Val F1: 0.8381
# Epoch 062 | LR: 0.000025 | Train Loss: 0.2411 | Val Loss: 0.5077 | Val F1: 0.9107
# Epoch 063 | LR: 0.000025 | Train Loss: 0.3240 | Val Loss: 0.7396 | Val F1: 0.8491
# Epoch 064 | LR: 0.000025 | Train Loss: 0.2506 | Val Loss: 0.7616 | Val F1: 0.8491
# Epoch 065 | LR: 0.000025 | Train Loss: 0.2601 | Val Loss: 0.6075 | Val F1: 0.8909
# Epoch 066 | LR: 0.000025 | Train Loss: 0.2765 | Val Loss: 0.6812 | Val F1: 0.8807
# Epoch 067 | LR: 0.000025 | Train Loss: 0.2569 | Val Loss: 0.7455 | Val F1: 0.8598
# Epoch 068 | LR: 0.000025 | Train Loss: 0.2335 | Val Loss: 0.7474 | Val F1: 0.8491
# Epoch 069 | LR: 0.000025 | Train Loss: 0.2833 | Val Loss: 0.5426 | Val F1: 0.8909
# Epoch 070 | LR: 0.000025 | Train Loss: 0.2324 | Val Loss: 0.5817 | Val F1: 0.8909
# Epoch 071 | LR: 0.000025 | Train Loss: 0.2313 | Val Loss: 0.5620 | Val F1: 0.8909
# Early stopping at epoch 71
#
# ========== Binary GraphSAGE Results ==========
# Accuracy:  0.9406
# Recall:    0.9048
# Precision: 0.9500
# F1:        0.9268
# AUC:       0.9354
# ===============================================
# Results saved to graphsage_binary_results.json

# %% [markdown]
# GraphSAGE – Multi‑Label Graph Classification (with per‑class weighted BCE)

# %%
import os
import pickle
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import DataLoader
from torch_geometric.nn import SAGEConv, global_mean_pool
from sklearn.metrics import f1_score, recall_score, precision_score, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_DIR = "GothamDataset2025/processed_features/gotham_graphs"
BATCH_SIZE = 16
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4
EPOCHS = 200
PATIENCE = 20
HIDDEN_DIM = 64
NUM_LAYERS = 2
DROPOUT = 0.2
LR_STEP = 30
LR_GAMMA = 0.5

#  LOAD & NORMALISE 
def load_graphs(split):
    with open(os.path.join(DATA_DIR, f"{split}_graphs.pkl"), 'rb') as f:
        return pickle.load(f)

with open(os.path.join(DATA_DIR, "norm_stats.json"), 'r') as f:
    norm_stats = json.load(f)

node_mean = torch.tensor(norm_stats["node_mean"], dtype=torch.float)
node_std  = torch.tensor(norm_stats["node_std"], dtype=torch.float)
node_dim  = norm_stats["node_dim"]

def normalise_graphs(graphs):
    for g in graphs:
        g.x = (g.x - node_mean) / (node_std + 1e-8)
        g.x = torch.clamp(g.x, -10, 10)

train_graphs = load_graphs('train')
val_graphs   = load_graphs('val')
test_graphs  = load_graphs('test')
print(f"Train: {len(train_graphs)}, Val: {len(val_graphs)}, Test: {len(test_graphs)}")

normalise_graphs(train_graphs)
normalise_graphs(val_graphs)
normalise_graphs(test_graphs)

#  BUILD MULTI-HOT LABELS 
attack_names = set()
for g in train_graphs:
    for name in g.edge_attack_names:
        if name != 'Benign':
            attack_names.add(name)
attack_names = sorted(list(attack_names))
num_classes = len(attack_names)
print(f"Number of attack classes: {num_classes}")
print("Classes:", attack_names)

class_to_idx = {name: i for i, name in enumerate(attack_names)}

def get_multihot_labels(graph):
    labels = torch.zeros(num_classes, dtype=torch.float)
    for name in graph.edge_attack_names:
        if name != 'Benign' and name in class_to_idx:
            labels[class_to_idx[name]] = 1.0
    return labels.unsqueeze(0)

for g in train_graphs:
    g.y_multihot = get_multihot_labels(g)
for g in val_graphs:
    g.y_multihot = get_multihot_labels(g)
for g in test_graphs:
    g.y_multihot = get_multihot_labels(g)

# Per‑class pos_weight
pos_counts = torch.stack([g.y_multihot for g in train_graphs]).sum(0)
neg_counts = len(train_graphs) - pos_counts
pos_weight = neg_counts / (pos_counts + 1e-6)
print("Pos_weight per class:", pos_weight.tolist())

train_loader = DataLoader(train_graphs, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_graphs, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_graphs, batch_size=BATCH_SIZE, shuffle=False)

#  GraphSAGE MODEL (Multi‑label) 
class GraphSAGEMulti(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers, dropout):
        super(GraphSAGEMulti, self).__init__()
        self.convs = nn.ModuleList()
        self.convs.append(SAGEConv(in_channels, hidden_channels))
        for _ in range(num_layers - 2):
            self.convs.append(SAGEConv(hidden_channels, hidden_channels))
        self.convs.append(SAGEConv(hidden_channels, hidden_channels))
        self.bns = nn.ModuleList([nn.BatchNorm1d(hidden_channels) for _ in range(num_layers)])
        self.dropout = dropout
        self.lin = nn.Linear(hidden_channels, out_channels)

    def forward(self, x, edge_index, batch):
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            x = self.bns[i](x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = global_mean_pool(x, batch)
        x = self.lin(x)
        return x

model = GraphSAGEMulti(
    in_channels=node_dim,
    hidden_channels=HIDDEN_DIM,
    out_channels=num_classes,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT
).to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight.to(DEVICE))
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=LR_STEP, gamma=LR_GAMMA)

best_val_loss = float('inf')
patience_counter = 0

for epoch in range(1, EPOCHS + 1):
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(DEVICE)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y_multihot)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    model.eval()
    val_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for data in val_loader:
            data = data.to(DEVICE)
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y_multihot)
            val_loss += loss.item() * data.num_graphs
            preds = torch.sigmoid(out).cpu().numpy()
            labels = data.y_multihot.cpu().numpy()
            all_preds.append(preds)
            all_labels.append(labels)
    val_loss /= len(val_loader.dataset)

    all_preds = np.vstack(all_preds)
    all_labels = np.vstack(all_labels)
    pred_binary = (all_preds >= 0.5).astype(int)
    macro_f1 = f1_score(all_labels, pred_binary, average='macro', zero_division=0)

    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    print(f"Epoch {epoch:03d} | LR: {current_lr:.6f} | Train Loss: {avg_loss:.4f} | Val Loss: {val_loss:.4f} | Val Macro F1: {macro_f1:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), os.path.join(DATA_DIR, "graphsage_multilabel_best.pth"))
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            print(f"Early stopping at epoch {epoch}")
            break

#  EVALUATION 
model.load_state_dict(torch.load(os.path.join(DATA_DIR, "graphsage_multilabel_best.pth")))
model.eval()

all_preds = []
all_labels = []
with torch.no_grad():
    for data in test_loader:
        data = data.to(DEVICE)
        out = model(data.x, data.edge_index, data.batch)
        preds = torch.sigmoid(out).cpu().numpy()
        labels = data.y_multihot.cpu().numpy()
        all_preds.append(preds)
        all_labels.append(labels)

all_preds = np.vstack(all_preds)
all_labels = np.vstack(all_labels)
pred_binary = (all_preds >= 0.5).astype(int)

per_class_recall = recall_score(all_labels, pred_binary, average=None, zero_division=0)
per_class_precision = precision_score(all_labels, pred_binary, average=None, zero_division=0)
per_class_f1 = f1_score(all_labels, pred_binary, average=None, zero_division=0)

macro_f1 = f1_score(all_labels, pred_binary, average='macro', zero_division=0)
macro_recall = recall_score(all_labels, pred_binary, average='macro', zero_division=0)
macro_precision = precision_score(all_labels, pred_binary, average='macro', zero_division=0)

pr_auc_per_class = []
for i in range(num_classes):
    if np.sum(all_labels[:, i]) > 0:
        try:
            auc = roc_auc_score(all_labels[:, i], all_preds[:, i])
        except:
            auc = 0.0
    else:
        auc = 0.0
    pr_auc_per_class.append(auc)
macro_pr_auc = np.mean(pr_auc_per_class)

print("\n========== Multi‑Label GraphSAGE Results ==========")
print(f"Macro F1:        {macro_f1:.4f}")
print(f"Macro Recall:    {macro_recall:.4f}")
print(f"Macro Precision: {macro_precision:.4f}")
print(f"Macro PR‑AUC:    {macro_pr_auc:.4f}")
print("\nPer‑class metrics:")
for i, name in enumerate(attack_names):
    print(f"  {name:20s} | Recall: {per_class_recall[i]:.4f} | Prec: {per_class_precision[i]:.4f} | F1: {per_class_f1[i]:.4f} | PR‑AUC: {pr_auc_per_class[i]:.4f}")
print("====================================================")

results = {
    "model": "GraphSAGE_multilabel",
    "loss": "BCEWithLogitsLoss (pos_weight)",
    "macro_f1": macro_f1,
    "macro_recall": macro_recall,
    "macro_precision": macro_precision,
    "macro_pr_auc": macro_pr_auc,
    "per_class": {
        name: {"recall": per_class_recall[i], "precision": per_class_precision[i], "f1": per_class_f1[i], "pr_auc": pr_auc_per_class[i]}
        for i, name in enumerate(attack_names)
    }
}
with open(os.path.join(DATA_DIR, "graphsage_multilabel_results.json"), "w") as f:
    json.dump(results, f, indent=4)
print("Results saved to graphsage_multilabel_results.json")
# Out:
# Train: 471, Val: 101, Test: 101
# Number of attack classes: 14
# Classes: ['C&C Communication', 'CoAP Amplification', 'File Download', 'Ingress Tool Transfer', 'Merlin C&C Communication', 'Merlin ICMP Flooding', 'Merlin TCP Flooding', 'Merlin UDP Flooding', 'Mirai C&C Communication', 'Reporting', 'TCP Scan', 'Telnet Brute Force', 'UDP Scan', 'Unknown']
# Pos_weight per class: [[23.789470672607422, 469.9995422363281, 93.19998168945312, 30.39999771118164, 5.633802890777588, 77.49998474121094, 66.28570556640625, 155.9999542236328, 38.249996185302734, 35.23076629638672, 23.789470672607422, 18.624998092651367, 11.729729652404785, 51.33332824707031]]
# Epoch 001 | LR: 0.000100 | Train Loss: 1.4150 | Val Loss: 1.7808 | Val Macro F1: 0.0510
# Epoch 002 | LR: 0.000100 | Train Loss: 1.3316 | Val Loss: 1.6978 | Val Macro F1: 0.0515
# Epoch 003 | LR: 0.000100 | Train Loss: 1.2815 | Val Loss: 1.7212 | Val Macro F1: 0.0492
# Epoch 004 | LR: 0.000100 | Train Loss: 1.2843 | Val Loss: 1.6471 | Val Macro F1: 0.0498
# Epoch 005 | LR: 0.000100 | Train Loss: 1.2664 | Val Loss: 1.6831 | Val Macro F1: 0.0479
# Epoch 006 | LR: 0.000100 | Train Loss: 1.2320 | Val Loss: 1.6513 | Val Macro F1: 0.0473
# Epoch 007 | LR: 0.000100 | Train Loss: 1.2419 | Val Loss: 1.6942 | Val Macro F1: 0.0330
# Epoch 008 | LR: 0.000100 | Train Loss: 1.1924 | Val Loss: 1.5982 | Val Macro F1: 0.0473
# Epoch 009 | LR: 0.000100 | Train Loss: 1.1498 | Val Loss: 1.5878 | Val Macro F1: 0.0460
# Epoch 010 | LR: 0.000100 | Train Loss: 1.1644 | Val Loss: 1.5788 | Val Macro F1: 0.0454
# Epoch 011 | LR: 0.000100 | Train Loss: 1.1193 | Val Loss: 1.5718 | Val Macro F1: 0.0454
# Epoch 012 | LR: 0.000100 | Train Loss: 1.1373 | Val Loss: 1.4790 | Val Macro F1: 0.0454
# Epoch 013 | LR: 0.000100 | Train Loss: 1.0971 | Val Loss: 1.4738 | Val Macro F1: 0.0454
# Epoch 014 | LR: 0.000100 | Train Loss: 1.1456 | Val Loss: 1.5213 | Val Macro F1: 0.0447
# Epoch 015 | LR: 0.000100 | Train Loss: 1.1098 | Val Loss: 1.5380 | Val Macro F1: 0.0447
# Epoch 016 | LR: 0.000100 | Train Loss: 1.2329 | Val Loss: 1.5142 | Val Macro F1: 0.0447
# Epoch 017 | LR: 0.000100 | Train Loss: 1.0779 | Val Loss: 1.4635 | Val Macro F1: 0.0447
# Epoch 018 | LR: 0.000100 | Train Loss: 1.0602 | Val Loss: 1.3517 | Val Macro F1: 0.0454
# Epoch 019 | LR: 0.000100 | Train Loss: 1.1505 | Val Loss: 1.3155 | Val Macro F1: 0.0454
# Epoch 020 | LR: 0.000100 | Train Loss: 1.0603 | Val Loss: 1.3332 | Val Macro F1: 0.0454
# Epoch 021 | LR: 0.000100 | Train Loss: 1.0876 | Val Loss: 1.2985 | Val Macro F1: 0.0460
# Epoch 022 | LR: 0.000100 | Train Loss: 1.0596 | Val Loss: 1.2967 | Val Macro F1: 0.0454
# Epoch 023 | LR: 0.000100 | Train Loss: 1.0498 | Val Loss: 1.3093 | Val Macro F1: 0.0454
# Epoch 024 | LR: 0.000100 | Train Loss: 1.0551 | Val Loss: 1.2251 | Val Macro F1: 0.0473
# Epoch 025 | LR: 0.000100 | Train Loss: 1.0060 | Val Loss: 1.1726 | Val Macro F1: 0.0460
# Epoch 026 | LR: 0.000100 | Train Loss: 1.0731 | Val Loss: 1.1962 | Val Macro F1: 0.0479
# Epoch 027 | LR: 0.000100 | Train Loss: 1.0932 | Val Loss: 1.1496 | Val Macro F1: 0.0460
# Epoch 028 | LR: 0.000100 | Train Loss: 1.1891 | Val Loss: 1.2531 | Val Macro F1: 0.0460
# Epoch 029 | LR: 0.000100 | Train Loss: 1.1235 | Val Loss: 1.2498 | Val Macro F1: 0.0454
# Epoch 030 | LR: 0.000050 | Train Loss: 1.1303 | Val Loss: 1.1985 | Val Macro F1: 0.0460
# Epoch 031 | LR: 0.000050 | Train Loss: 1.2753 | Val Loss: 1.3758 | Val Macro F1: 0.0454
# Epoch 032 | LR: 0.000050 | Train Loss: 0.9526 | Val Loss: 1.2825 | Val Macro F1: 0.0454
# Epoch 033 | LR: 0.000050 | Train Loss: 0.9653 | Val Loss: 1.2808 | Val Macro F1: 0.0454
# Epoch 034 | LR: 0.000050 | Train Loss: 0.9591 | Val Loss: 1.2830 | Val Macro F1: 0.0454
# Epoch 035 | LR: 0.000050 | Train Loss: 1.0258 | Val Loss: 1.2788 | Val Macro F1: 0.0454
# Epoch 036 | LR: 0.000050 | Train Loss: 0.9123 | Val Loss: 1.2316 | Val Macro F1: 0.0454
# Epoch 037 | LR: 0.000050 | Train Loss: 1.1897 | Val Loss: 1.2643 | Val Macro F1: 0.0454
# Epoch 038 | LR: 0.000050 | Train Loss: 1.1454 | Val Loss: 1.2271 | Val Macro F1: 0.0460
# Epoch 039 | LR: 0.000050 | Train Loss: 1.1331 | Val Loss: 1.2438 | Val Macro F1: 0.0454
# Epoch 040 | LR: 0.000050 | Train Loss: 0.9529 | Val Loss: 1.3550 | Val Macro F1: 0.0447
# Epoch 041 | LR: 0.000050 | Train Loss: 0.9812 | Val Loss: 1.2958 | Val Macro F1: 0.0454
# Epoch 042 | LR: 0.000050 | Train Loss: 1.2205 | Val Loss: 1.2091 | Val Macro F1: 0.0454
# Epoch 043 | LR: 0.000050 | Train Loss: 1.0399 | Val Loss: 1.1726 | Val Macro F1: 0.0454
# Epoch 044 | LR: 0.000050 | Train Loss: 0.9059 | Val Loss: 1.3068 | Val Macro F1: 0.0447
# Epoch 045 | LR: 0.000050 | Train Loss: 0.9093 | Val Loss: 1.2479 | Val Macro F1: 0.0454
# Epoch 046 | LR: 0.000050 | Train Loss: 1.2699 | Val Loss: 1.2473 | Val Macro F1: 0.0447
# Epoch 047 | LR: 0.000050 | Train Loss: 0.9308 | Val Loss: 1.2236 | Val Macro F1: 0.0454
# Early stopping at epoch 47
#
# ========== Multi‑Label GraphSAGE Results ==========
# Macro F1:        0.0360
# Macro Recall:    0.0578
# Macro Precision: 0.0261
# Macro PR‑AUC:    0.0306
#
# Per‑class metrics:
#   C&C Communication    | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   CoAP Amplification   | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   File Download        | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Ingress Tool Transfer | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin C&C Communication | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin ICMP Flooding | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin TCP Flooding  | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Merlin UDP Flooding  | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Mirai C&C Communication | Recall: 0.8095 | Prec: 0.3656 | F1: 0.5037 | PR‑AUC: 0.4282
#   Reporting            | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   TCP Scan             | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Telnet Brute Force   | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   UDP Scan             | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
#   Unknown              | Recall: 0.0000 | Prec: 0.0000 | F1: 0.0000 | PR‑AUC: 0.0000
# ====================================================
# Results saved to graphsage_multilabel_results.json
